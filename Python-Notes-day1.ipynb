# %%
from IPython.display import Image
Image('0.png')

# %% [markdown]
# ## PYTHON

# %%
print("welcome to Python coding")
print('welcome to Python coding')
# Out:
# welcome to Python coding
# welcome to Python coding

# %%
## wrong usuage
print('Great Learning, welcome to Python coding')
# Out:
# Great Learning, welcomecome to Python coding

# %% [markdown]
# ## Variables

# %%
from IPython.display import Image
Image('1.png')

# %%
a = 3
a
# Out:
# 3

# %%
b = a
c = a
c
# Out:
# 3

# %%
a = 'hello'

# %%
Image('1.1.png')

# %% [markdown]
# ### 1. int

# %%
a = 4
type(a)
# Out:
# int

# %% [markdown]
# ### 2. float

# %%
a = 4.5
type(a)
# Out:
# float

# %% [markdown]
# ### 3.  Complex Numbers

# %%
a = 4+2j
type(a)
# Out:
# complex

# %% [markdown]
# ### 4. String

# %%
s = '4'
type(s)
# Out:
# str

# %%
s = 'hi'
print(s[1])
print(len(s) )      
print(s + ' there')
# Out:
# i
# 2
# hi there

# %% [markdown]
# ### 4.Boolean

# %%
True and False
# Out:
# False

# %% [markdown]
# # Python Operators

# %%
Image('2.png')

# %% [markdown]
# ## 1. Arithmetic Operators

# %%
Image('3.png')

# %%
x = 240
y = 1
x+y
# Out:
# 241

# %% [raw]
# ### The most common arithmetic Operators are
#                                                 + (Addition)
#                                                 – (Subtraction)
#                                                 * (Multiplication)
#                                                 / (Division)
#                                                 % (Modulus)

# %% [markdown]
# #### 1. // (Division Operators)

# %%
a = 27
b = 2

# %%
a // b
# Out:
# 13

# %% [markdown]
# #### 2. What is difference between / and // Operator

# %%
a / b   #  Division Operator always give floating point value
# Out:
# 13.5

# %%
a // b  # No float
# Out:
# 13

# %% [markdown]
# #### 3. + Addition Operator

# %%
# Adding two Variables
A = 30
B = 20
C = A+B
C
# Out:
# 50

# %%
# Adding two strings
a = 'Technical' + 'Seek'
a
# Out:
# 'TechnicalSeek'

# %%
# Adding the values
a = 4 + 3 + 4
a
# Out:
# 11

# %%
# Adding the "Strings" + '4' 
a = 'Technical' + 'Seek' +'4' # here 4 is string
a
# Out:
# 'TechnicalSeek4'

# %% [markdown]
# #### 4. - subtraction Operator

# %%
# subtracting two Variables
A = 30
B = 20
C = A-B
C
# Out:
# 10

# %%
# subtracting two strings but you can not 
a = 'Technical' - 'Seek'
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-fd16a9d73071> in <module>
#       1 # Adding two strings
# ----> 2 a = 'Seek' - 'k'
#       3 a
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# subtracting the values
a = 4 - 3 - 4
a
# Out:
# -3

# %% [markdown]
# #### 5. * Operator

# %%
# multiplicating two Variables
A = 30
B = 20
C = A*B
C
# Out:
# 600

# %%
# multiplicating two strings but you can not 
a = 'abc' * 3
a
# Out:
# 'abcabcabc'

# %% [markdown]
# #### 6. % Modulus

# %%
# Modulus - Find the remainder
A = 30.5
B = 20
C = A % B
C
# Out:
# 10.5

# %%
Image('4.png')

# %%
x = 100
y = 12

# %%
# Output: x > y is False
print('x > y  is',x>y)
# Out:
# x > y  is True

# %%
# Output: x < y is True
print('x < y  is',x<y)
# Out:
# x < y  is False

# %%
# Output: x == y is False
print('x == y is',x==y)
# Out:
# x == y is False

# %%
# Output: x != y is True
print('x != y is',x!=y)
# Out:
# x != y is True

# %%
# Output: x >= y is False
print('x >= y is',x>=y)
# Out:
# x >= y is True

# %%
# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x <= y is False

# %%
Image('5.png')

# %%
Image('6.png')

# %%
x = True
y = False

# Output: x and y is False
print('x and y is',x and y)
# Out:
# x and y is False

# %%
Image('7.png')

# %%
x = True
y = False

# Output: x or y is True
print('x or y is',x or y)
# Out:
# x or y is True

# %%
Image('8.png')

# %%
x = True
y = False

# Output: not x is False
print('not x is',not x)
# Out:
# not x is False

# %%
Image('9.png')

# %%
a=10 # binary 1010
b=7  # binary 0111
print(a&b)
# Out:
# 2

# %%
a=20 
b=17  
print(a|b)
# Out:
# 21

# %%
a=60 
b=17  
print(a^b)
# Out:
# 45

# %%
a = 20
print(~a)
# Out:
# -21

# %%
a=50
print(a<<1)
# Out:
# 100

# %%
print(a>>1)
# Out:
# 25

# %%
Image('10.png')

# %%
a=3
b=4

a+=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 7
# b: 4

# %%
a=3
b=4

a*=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 12
# b: 4

# %%
a=3
b=4

a/=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0.75
# b: 4

# %%
a=3
b=4

a%=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 3
# b: 4

# %%
a=3
b=4

a**=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 81
# b: 4

# %%
a=3
b=4

a//=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0
# b: 4

# %% [markdown]
# ### Concatenate

# %% [markdown]
# ###### 1.Concatenating and Joining Strings

# %%
'a' + 'b' + 'c'
# Out:
# 'abc'

# %%
'do' * 3
# Out:
# 'dododo'

# %% [markdown]
# ###### 2. Concatenating With .Join()

# %%
strings = ['do', 're', 'mi']
' , '.join(strings)
# Out:
# 'do , re , mi'

# %%
'b'.join(['a'])
# Out:
# 'a'

# %% [markdown]
# ### Position

# %%
a = [3, 4, 1, 3, 4, 5]

# %%
a.index(4)
# Out:
# 1

# %% [markdown]
# ### length

# %%
a = [3, 4, 1, 3, 4, 5]

# %%
print('a length is', len(a))
# Out:
# a length is 6

# %% [markdown]
# ## IF Statements

# %%
Image('11.png')

# %% [markdown]
# #### IF Syntax

# %% [raw]
# if condition:
#     statements

# %% [markdown]
# #### IF Pseudocode (to find if a number is greater than 235)

# %% [raw]
# Assigning i = 100
# and if condition i is greater than 235, go to step 3, if not directly go to step 4
# print '100 is greater than 235'
# print'End of If Condition'

# %% [markdown]
# # IF - ELSE Statements

# %%
Image('12.png')

# %% [markdown]
# #### IF-ELSE syntax

# %% [raw]
# if condition:
#     statements
# else:
#     statements

# %% [markdown]
# #### IF-ELSE Pseudocode (to check if a number is a number is even or odd)

# %% [raw]
# Create input number
# Assigning i equal to (number % 2)
# If condition i is less than one go to step 4, else go to step 5
# print "This is an even number"
# print "This is an odd number"

# %% [markdown]
# ## NESTED- IF Statements

# %%
Image('13.png')

# %% [markdown]
# ##### NESTED- IF  syntax

# %% [raw]
# if condition:
#     if condition:
#         statements
#     else:
#         statements
# else:
# statements

# %% [markdown]
# #### NESTED-IF Pseudocode (to find three brackets of age : <25, 25 and 100, >100

# %% [raw]
# Create input number and Assigning to X
# if condition x is greater than 25 go to step 5 , else go to step 6
# if x is greater than 100 go to step 4, else go to step 5
# print('You are too old')
# print('you are of the right age')
# print('You are too young')

# %%
Image('14.png')

# %% [markdown]
# #### WHILE LOOP Syntax

# %% [raw]
# while condition:
#      statements

# %% [markdown]
# ##### while Loop Pseudocode (to print the first 10 natural numbers)

# %% [raw]
# Assigning x = 0
# while loop condition x is greater than 10 go to step 3
# print x and go to step 4
# each loop iteration x increment equal to 1

# %% [markdown]
# # FOR LOOP

# %%
Image('15.png')

# %% [markdown]
# #### Syntax of for Loop

# %%
for i in sequence:
    Body of for

# %% [markdown]
# ##### For Loop Pseudocode (to print the sum of all elements in the list)

# %%
Create simple list variable numbers equal to [6, 5, 3, 8, 4, 2, 5, 4, 11, 43]
variable sum equal to zero
create Condition for loop i in the numbers
    sum equal to sum+i here each loop iterated
print sum
